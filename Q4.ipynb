# %% [markdown]
# # Import libraries and define a few variables

# %%
import matplotlib.pyplot as plt
import ecg_plot
import numpy as np
import os 
import neurokit2 as nk
import random
import warnings

from scipy.io import loadmat
from glob import glob

warnings.filterwarnings('ignore')

# %%
path_mat = glob('Training_2/*.mat')
len(path_mat)
# Out:
# 3453

# %% [markdown]
# # Define function

# %%
def load_data(filename,calib):
    
    x = loadmat(filename)
    data = np.asarray(x['val'], dtype=np.float64)
    
    lead_1 = data[0]/calib    
    lead_2 = data[1]/calib
    lead_3 = data[2]/calib

    avr = data[3]/calib
    avl = data[4]/calib
    avf = data[5]/calib

    v1 = data[6]/calib
    v2 = data[7]/calib
    v3 = data[8]/calib
    v4 = data[9]/calib
    v5 = data[10]/calib
    v6 = data[11]/calib
    
    new_file = filename.replace('.mat','.hea')
    input_header_file = os.path.join(new_file)
    with open(input_header_file,'r') as f:
        header_data=f.readlines()
        
    gender = header_data[-5][6:].split('\n')[0]
    
    dict_1 = {'lead_1': lead_1,
              'lead_2': lead_2,
              'lead_3': lead_3,
              'avr': avr,
              'avl': avl,
              'avf': avf,
              'v1': v1,
              'v2': v2,
              'v3': v3,
              'v4': v4,
              'v5': v5,
              'v6': v6} 
    
    return dict(dict_1) ,gender,header_data

# %% [markdown]
# # Fixed variables

# %%
baseline = 16
sr = 500
calib = 1000
n = 1540 #selected this because of clear visualizatins

# %%
extracted_data = load_data(path_mat[n],calib)
lead_data = extracted_data[0]
lead_data
# Out:
# {'lead_1': array([ 0.004,  0.011, -0.007, ..., -0.095, -0.088, -0.074]),
#  'lead_2': array([-0.062, -0.082, -0.08 , ..., -0.119, -0.112, -0.103]),
#  'lead_3': array([-0.066, -0.093, -0.073, ..., -0.025, -0.024, -0.029]),
#  'avr': array([0.028, 0.035, 0.043, ..., 0.107, 0.1  , 0.088]),
#  'avl': array([ 0.035,  0.052,  0.032, ..., -0.036, -0.032, -0.022]),
#  'avf': array([-0.063, -0.087, -0.076, ..., -0.072, -0.068, -0.066]),
#  'v1': array([-0.03 , -0.038, -0.025, ..., -0.014, -0.014, -0.008]),
#  'v2': array([-0.16 , -0.223, -0.191, ..., -0.173, -0.165, -0.18 ]),
#  'v3': array([-0.228, -0.323, -0.284, ..., -0.246, -0.235, -0.257]),
#  'v4': array([-0.165, -0.229, -0.199, ..., -0.196, -0.187, -0.207]),
#  'v5': array([-0.126, -0.177, -0.155, ..., -0.163, -0.15 , -0.161]),
#  'v6': array([-0.085, -0.121, -0.105, ..., -0.119, -0.117, -0.135])}

# %% [markdown]
# # Graph plotting

# %%
_, rpeaks = nk.ecg_peaks(lead_data['lead_1'], sampling_rate=sr)
_, waves_peak = nk.ecg_delineate(lead_data['lead_1'], 
                                 rpeaks, 
                                 sampling_rate=sr, 
                                 method="peak", 
                                 show=True, 
                                 show_type='all')

# %% [markdown]
# ## Required graph

# %%
_, rpeaks = nk.ecg_peaks(lead_data['lead_2'], sampling_rate=sr)
_, waves_peak = nk.ecg_delineate(lead_data['lead_2'], 
                                 rpeaks, 
                                 sampling_rate=sr, 
                                 method="peak", 
                                 show=True, 
                                 show_type='all')

# %%
_, rpeaks = nk.ecg_peaks(lead_data['lead_3'], sampling_rate=sr)
_, waves_peak = nk.ecg_delineate(lead_data['lead_3'], 
                                 rpeaks, 
                                 sampling_rate=sr, 
                                 method="peak", 
                                 show=True, 
                                 show_type='all')

# %%
_, rpeaks = nk.ecg_peaks(lead_data['avr'], sampling_rate=sr)
_, waves_peak = nk.ecg_delineate(lead_data['avr'], 
                                 rpeaks, 
                                 sampling_rate=sr, 
                                 method="peak", 
                                 show=True, 
                                 show_type='all')

# %%
_, rpeaks = nk.ecg_peaks(lead_data['avl'], sampling_rate=sr)
_, waves_peak = nk.ecg_delineate(lead_data['avl'], 
                                 rpeaks, 
                                 sampling_rate=sr, 
                                 method="peak", 
                                 show=True, 
                                 show_type='all')

# %%
_, rpeaks = nk.ecg_peaks(lead_data['avf'], sampling_rate=sr)
_, waves_peak = nk.ecg_delineate(lead_data['avf'], 
                                 rpeaks, 
                                 sampling_rate=sr, 
                                 method="peak", 
                                 show=True, 
                                 show_type='all')

# %%
_, rpeaks = nk.ecg_peaks(lead_data['v1'], sampling_rate=sr)
_, waves_peak = nk.ecg_delineate(lead_data['v1'], 
                                 rpeaks, 
                                 sampling_rate=sr, 
                                 method="peak", 
                                 show=True, 
                                 show_type='all')

# %%
_, rpeaks = nk.ecg_peaks(lead_data['v2'], sampling_rate=sr)
_, waves_peak = nk.ecg_delineate(lead_data['v2'], 
                                 rpeaks, 
                                 sampling_rate=sr, 
                                 method="peak", 
                                 show=True, 
                                 show_type='all')

# %%
_, rpeaks = nk.ecg_peaks(lead_data['v3'], sampling_rate=sr)
_, waves_peak = nk.ecg_delineate(lead_data['v3'], 
                                 rpeaks, 
                                 sampling_rate=sr, 
                                 method="peak", 
                                 show=True, 
                                 show_type='all')

# %%
_, rpeaks = nk.ecg_peaks(lead_data['v4'], sampling_rate=sr)
_, waves_peak = nk.ecg_delineate(lead_data['v4'], 
                                 rpeaks, 
                                 sampling_rate=sr, 
                                 method="peak", 
                                 show=True, 
                                 show_type='all')

# %%
_, rpeaks = nk.ecg_peaks(lead_data['v5'], sampling_rate=sr)
_, waves_peak = nk.ecg_delineate(lead_data['v5'], 
                                 rpeaks, 
                                 sampling_rate=sr, 
                                 method="peak", 
                                 show=True, 
                                 show_type='all')

# %%
_, rpeaks = nk.ecg_peaks(lead_data['v6'], sampling_rate=sr)
_, waves_peak = nk.ecg_delineate(lead_data['v6'], 
                                 rpeaks, 
                                 sampling_rate=sr, 
                                 method="peak", 
                                 show=True, 
                                 show_type='all')
